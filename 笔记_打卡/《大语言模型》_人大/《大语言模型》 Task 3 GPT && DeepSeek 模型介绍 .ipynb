# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaoshu-root/Code-related-courses/blob/main/%E7%AC%94%E8%AE%B0_%E6%89%93%E5%8D%A1/%E3%80%8A%E5%A4%A7%E8%AF%AD%E8%A8%80%E6%A8%A1%E5%9E%8B%E3%80%8B_%E4%BA%BA%E5%A4%A7/%E3%80%8A%E5%A4%A7%E8%AF%AD%E8%A8%80%E6%A8%A1%E5%9E%8B%E3%80%8B%20Task%203%20GPT%20%26%26%20DeepSeek%20%E6%A8%A1%E5%9E%8B%E4%BB%8B%E7%BB%8D%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - [x] 快速过 [PPT](https://www.datawhale.cn/learn/content/107/3294)
# - [x] 边看 [视频](https://www.bilibili.com/video/BV1VhRKYEENT/?vd_source=f722c145eae91a5b6df588c0ca0f6dbb) 边整理笔记

# %% [markdown]
# 整理自：
#
# 【教程地址】https://www.datawhale.cn/learn/summary/107
# * https://github.com/datawhalechina/llmbook

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ![a15fb4099e7fb68785e733df56b5764.png](data:image/png;base64,...)

# %% [markdown]
# ![00b749c21c7a6bbf9db76deb921520b.png](data:image/png;base64,...)

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 监督微调 (Supervised Fine-Tuning, SFT)

# %% [markdown]
# 拒绝采样 (rejection sampling, RS)

# %% [markdown]
# 〔 **DeepSeek-R1** =
# 数千个冷启动数据 微调 DeepSeek-V3-Base 模型 +
#
# 面向推理的强化学习 (GRPO) +
#
# 基于 RL 快收敛时的 checkpoint， **拒绝采样** 创建 新的**监督微调**数据，重新训练 DeepSeek-V3- base 模型 +
#
# 基于来自所有场景的提示，检查点进行 RL 过程 〕
#
#
# ————————————
#
# 〔 **DeepSeek-R1-Zero** = 基础模型 + RL 〕
