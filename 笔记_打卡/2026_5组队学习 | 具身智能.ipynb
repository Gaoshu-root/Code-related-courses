# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaoshu-root/Code-related-courses/blob/main/%E7%AC%94%E8%AE%B0_%E6%89%93%E5%8D%A1/2026_5%E7%BB%84%E9%98%9F%E5%AD%A6%E4%B9%A0%20%7C%20%E5%85%B7%E8%BA%AB%E6%99%BA%E8%83%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * [学习资料链接](https://github.com/datawhalechina/every-embodied/tree/main/16-%E4%B8%93%E9%A2%98%E7%BB%84%E9%98%9F%E5%AD%A6%E4%B9%A0/01-%E8%BE%BE%E6%91%A9%E9%99%A2%E7%BB%84%E9%98%9F%E5%AD%A6%E4%B9%A0)

# %% [markdown]
# # Task01：理论与趋势

# %% [markdown]
# <mark>具身智能</mark> = 能在物理世界里<u>感知、理解、决策并行动</u>的智能系统。
#
# <font color=red>真实世界</font>有空间、时间、摩擦、遮挡、碰撞、延迟、误差和失败成本。
#
# **系统**有一个能够**和世界发生真实交互的载体**。这个载体可以是：
# - 机械臂
# - 双足或轮式人形机器人
# - 四足机器人
# - 无人车、无人机、无人船
# - 搭载 AI 的工业装备

# %% [markdown]
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# <font size=4>**应用场景：**</font>
# - 工厂里的分拣、装配、搬运
# - 家庭里的整理、递送、陪伴
# - 仓储物流里的拣选、转运、上架
# - 危险环境下的**巡检、救援、勘探**

# %% [markdown]
# 1. 路径选择争议："感知-认知-决策-执行" 的实现，数据和模型孰重孰轻？
# 2. 本体构型争议：打造通用的唯一终极形态还是面向场景的专用构型？
# 3. 数据方案争议：<font color=red>真实数据与仿真/合成数据如何选择、处理和混合训练？</font>

# %% [markdown]
# <font color=red><font size=4>四大核心挑战：</font></font>
#
# 1. 系统层面：<font color=red>软硬件非标准化、集成度低、协议不统一，制约了规模化部署</font>。
# 2. 数据层面：<font color=red>高质量数据规模有限、采集成本高昂，且仿真环境与真实物理世界采集的数据之间存在鸿沟</font>(Sim2Real Gap）。
# 3. 模型层面：技术范式尚未定型，具身大模型的 RLHF 方法仍在探索之中。
#    * 待解决：<font color=red>类推能力、长时序规划、稳定控制</font>
# 4. 人才层面：领域复合型人才稀缺，AI 开发者需同时具备算法、硬件、控制等全栈能力。

# %% [markdown]
# 6.1 为什么有潜力
#
# 它**直接连接**工业、物流、家庭、医疗、巡检等**真实需求**
#
# **难度大**：它能把多模态模型、机器人控制、仿真平台、数据系统串成完整闭环
#
# 它**具备**明显的**工程和产业价值**，而不仅仅是论文价值

# %% [markdown]
# 任务2：“我心中的一个具身智能应用场景”
#
# 希望具身智能深度参与人类**养育下一代**以及**养老陪护**。将家庭从 “抚养-赡养” 的功利性互助联盟，转变为更纯粹的情感共同体。
#
#
# *   承担大量**重复性、体力型的看护工作**，例如：24 小时安全监护(防跌落、异物入口）、辅助喂养、陪伴玩耍、进行标准化的早期启蒙互动等。将父母从<font color=red>繁琐的、消耗性的育儿事务</font>中部分解放出来，让他们在有限的亲子时间里，专注于更高价值的**情感交流、深度陪伴和价值观引导**。
# * **为每个孩子提供定制化的发展建议**，**预警**自闭症、注意力缺陷多动障碍(ADHD)等，**及早干预**。
# * **保护孩子的好奇心和探索欲**：孩子可以向它问任何 “愚蠢” 的问题，无需担心被嘲笑或责备。
#
# * ——————
# * 承担起最艰苦的养老护理工作：帮助**翻身**、移动、**如厕、清洁、喂饭**、24小时防跌倒监测与**应急响应**、出门溜达陪护、协助长辈与时俱进等。

# %% [markdown]
# # Task02：技术透视

# %% [markdown]
# ## VLA(Vision-Language-Action) | 视觉-语言-动作
#
#
# <font color=red>对三维空间结构、物理约束和接触关系的显式建模</font>往往还<font color=red>不够强</font>。也正因为这些局限，研究者才会继续探索**世界模型**、**显式空间表示**以及更强的**规划**机制。

# %% [markdown]
# 🟩 查看这篇文章的最新被引用 https://openvla.github.io/
#
# 🟩  VLA 综述， 确认一些模型的细节。https://github.com/datawhalechina/every-embodied/blob/main/06-%E7%AD%96%E7%95%A5%E6%8A%93%E5%8F%96%E6%88%96%E6%8A%93%E5%8F%96VLA/01VLA%E7%9B%B8%E5%85%B3%E6%80%BB%E7%BB%93%E7%BB%BC%E8%BF%B0.md

# %% [markdown]
# ## 世界模型
#
# VLA： “**直接**把看见的和听到的**映射成动作**”。
#
# 世界模型：“**先预测世界会怎么变**，再决定动作怎么做”。
#
#
# VLA(响应式系统) —> 世界模型(规划式系统)

# %% [markdown]
# 世界模型通常会尝试**建模三类关系**：当前环境状态是什么、某个动作执行后环境会如何变化、在若干可能的未来演化中哪条路径更接近目标。

# %% [markdown]
# <img src="data:image/png;base64,..." width="550">

# %% [markdown]
# 模型、仿真、数据和硬件

# %% [markdown]
# 🟩  任务： 对比 Pi0、GR00T、RynnBrain 三者分别更强调什么能力
#
#  π 系列：https://www.pi.website/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Task03
#
# 数据、训练、调试、部署

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Task04

# %% [markdown]
# ![image.png](data:image/png;base64,...)
