# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaoshu-root/Code-related-courses/blob/main/mathematics-modeling_%20Notes/%E3%80%8A%E6%95%B0%E5%AD%A6%E5%BB%BA%E6%A8%A1%E3%80%8B_%E5%8D%8E%E4%B8%AD%E5%86%9C%E4%B8%9A%E5%A4%A7%E5%AD%A6%20%E7%AC%AC%2016%20%E6%AC%A1%E5%BC%80%E8%AF%BE/4.4%20%E6%8C%87%E6%B4%BE%E9%97%AE%E9%A2%98%20%E3%80%94%E7%94%A8%20scipy.optimize.linear_sum_assignment%20%E6%B1%82%E8%A7%A3%E3%80%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 链接： [《数学建模》_华中农业大学 第 16 次开课](https://www.icourse163.org/learn/HZAU-1001658002?tid=1472021457#/learn/content)

# %% [markdown]
# ## 例 1

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# ### 矩阵覆盖法

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# ### 用 scipy.optimize.linear_sum_assignment 求解

# %%
"""
用 scipy.optimize.linear_sum_assignment 求解
"""

# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.linear_sum_assignment.html#scipy.optimize.linear_sum_assignment

# 根据题目信息， 输入 cost
import numpy as np
cost = np.array([[2, 15, 13, 4],
     [10, 4, 14, 15],
     [9, 14, 16, 13],
     [7, 8, 11, 9]])

from scipy.optimize import linear_sum_assignment
row_ind, col_ind = linear_sum_assignment(cost)
print("指派的对应任务的编号为： ", col_ind+1)
print("完成任务的最少时间为：", cost[row_ind, col_ind].sum())
# Out:
# 指派的对应任务的编号为：  [4 2 1 3]
# 完成任务的最少时间为： 28

# %% [markdown]
# ## 例 2

# %% [markdown]
# <img src="data:image/png;base64,..." width="700">

# %%
"""
用 scipy.optimize.linear_sum_assignment 求解
"""

# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.linear_sum_assignment.html#scipy.optimize.linear_sum_assignment

# 根据题目信息， 输入 cost
import numpy as np
cost = np.array([[12, 7, 9, 7, 9],
     [8, 9, 6, 6, 6],
     [7, 17, 12, 14, 9],
     [15, 14, 6, 6, 10],
     [4, 10, 7, 10, 9]])

from scipy.optimize import linear_sum_assignment
row_ind, col_ind = linear_sum_assignment(cost)
print("分配的对应编号为： ", col_ind+1)
# print("最低成本为：", cost[row_ind, col_ind].sum())
# Out:
# 分配的对应编号为：  [2 3 5 4 1]

# %% [markdown]
# ## 例 3 选拔队员

# %% [markdown]
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# <img src="data:image/png;base64,..." width="500">

# %%
"""
用 scipy.optimize.linear_sum_assignment 求解
"""

# https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.linear_sum_assignment.html#scipy.optimize.linear_sum_assignment

# 根据题目信息， 输入 cost
import numpy as np
cost = np.array([[66, 57, 78, 70, 77],
     [65, 61, 74, 74, 71],
     [87, 66, 69, 69, 84],
     [59, 53, 59, 57, 62]])

from scipy.optimize import linear_sum_assignment
row_ind, col_ind = linear_sum_assignment(cost)
print("选拔的队员编号为： ", col_ind+1)
# print("最低成本为：", cost[row_ind, col_ind].sum())
# Out:
# 选拔的队员编号为：  [2 1 3 4]
