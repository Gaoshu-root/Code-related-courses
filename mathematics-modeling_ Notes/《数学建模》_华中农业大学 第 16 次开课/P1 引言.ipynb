# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaoshu-root/Code-related-courses/blob/main/mathematics-modeling_%20Notes/%E3%80%8A%E6%95%B0%E5%AD%A6%E5%BB%BA%E6%A8%A1%E3%80%8B_%E5%8D%8E%E4%B8%AD%E5%86%9C%E4%B8%9A%E5%A4%A7%E5%AD%A6%20%E7%AC%AC%2016%20%E6%AC%A1%E5%BC%80%E8%AF%BE/P1%20%E5%BC%95%E8%A8%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 链接： [《数学建模》_华中农业大学 第 16 次开课](https://www.icourse163.org/learn/HZAU-1001658002?tid=1472021457#/learn/content)

# %% [markdown]
# <img src="data:image/png;base64,..." width="200">

# %% [markdown]
# 数学模型 (Mathematical Model)： 现实对象的数学表现形式。
#
# 数学建模 (Mathematical Modeling)： 建立数学模型的全过程 (包括**表述、求解、解释、检验**等)

# %% [markdown]
# ## 数学建模的步骤

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# ### 1、问题的分析

# %% [markdown]
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# ### 2、符号说明

# %% [markdown]
# <img src="data:image/png;base64,..." width="200">

# %% [markdown]
# ### 3、模型的假设

# %% [markdown]
# <img src="data:image/png;base64,..." width="300">

# %% [markdown]
# ### 4、模型的建立

# %% [markdown]
# <img src="data:image/png;base64,..." width="250">

# %% [markdown]
# ### 5、模型的求解

# %% [markdown]
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# ### 6、结果的分析

# %% [markdown]
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# ### 7、模型的检验

# %% [markdown]
# <img src="data:image/png;base64,..." width="450">

# %% [markdown]
# ### 8、模型的应用

# %% [markdown]
# <img src="data:image/png;base64,..." width="450">

# %% [markdown]
# ### 总体

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## 课程内容

# %% [markdown]
# <img src="data:image/png;base64,..." width="300">

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# <img src="data:image/png;base64,..." width="350">

# %% [markdown]
# ## 如何学习数学建模

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">

# %% [markdown]
# <img src="data:image/png;base64,..." width="400">
