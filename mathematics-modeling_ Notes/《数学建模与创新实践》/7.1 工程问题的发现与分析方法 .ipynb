# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaoshu-root/Code-related-courses/blob/main/mathematics-modeling_%20Notes/%E3%80%8A%E6%95%B0%E5%AD%A6%E5%BB%BA%E6%A8%A1%E4%B8%8E%E5%88%9B%E6%96%B0%E5%AE%9E%E8%B7%B5%E3%80%8B/7.1%20%E5%B7%A5%E7%A8%8B%E9%97%AE%E9%A2%98%E7%9A%84%E5%8F%91%E7%8E%B0%E4%B8%8E%E5%88%86%E6%9E%90%E6%96%B9%E6%B3%95%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [《数学建模与创新实践》_第 12 次开课](https://www.icourse163.org/course/0701XUST003-1206498809?outVendor=zw_mooc_pclszykctj_)

# %% [markdown]
# 问题： **现状** 与 **期待的状态** 之间的**差距**。

# %% [markdown]
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# <img src="data:image/png;base64,..." width="700">

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### 发现问题的 3 种情境

# %% [markdown]
# 发现问题：
#
# 1、啤酒瓶打开需要起子不方便 ——> 易拉环

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### 准确定义问题的方法： 5 Why 法

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# 问题： 美国华盛顿广场的杰弗逊纪念馆大楼 外墙斑驳陈旧。
#
# 1、为什么会出现斑驳？(因为冲洗墙壁所含的清洁剂对建筑物有强烈的腐蚀作用，而<font color=red>该大厦墙壁每日被冲洗的次数**大大多于**其它建筑</font>，因此腐蚀比较严重) **——>**
#
# 2、为什么每日冲洗？(因为大厦被<font color=red>大量的鸟粪</font>弄脏) **——>**
#
# 3、为什么这么多鸟粪？(因为大厦周围聚集了<font color=red>很多燕子</font>) **——>**
#
# 4、为什么燕子专爱聚集在这里？(因为建筑物上有燕子爱吃的<font color=red>蜘蛛</font>) **——>**
#
# 5、为什么这里的蜘蛛特别多？ (因为墙上有蜘蛛爱吃的<font color=red>飞虫</font>) **——>**
#
# 6、 为什么这里的飞虫这么多？(飞虫在这里繁殖特别快) **——>**
#
# 7、为什么飞虫在这里繁殖特别快？(因为开着的窗<font color=red>阳光充足</font>，大量飞虫聚集在此，超常繁殖) **——>**
#
# <font color=blue>拉上窗帘</font>

# %% [markdown]
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# <img src="data:image/png;base64,..." width="500">
